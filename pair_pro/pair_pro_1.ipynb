# %%
# 問題１

amount = 1
day = 1

list_day_grain = [1]

list_total_grain = [1]

for _ in range(100-1):
    day *= 2
    list_day_grain.append(day)
    amount += day
    list_total_grain.append(amount)
    
# print(list_day_grain)
# print("100日目には合計で{}個".format(list_day_grain[-1]))
# print(list_total_grain)

# %% [markdown]
# 1日目から100日目までの「その日にもらう米の数」と「その日までに累計で貰う米の数」の推移を折れ線グラフで表現してください。（縦軸が米の数、横軸が日数）

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("amount of rice")
plt.xlabel("day")
plt.ylabel("count")
plt.plot(list_day_grain, label="day_grains")  # 「リスト名」のところにリストの変数名を入れる
plt.plot(list_total_grain, label="total_grains")  # 「リスト名」のところにリストの変数名を入れる
plt.legend()
plt.show()

# %% [markdown]
# 【問題2】100日目以外の米粒の数

# %%
def compute_sorori_shinzaemon(n_days=100):
    """曽呂利新左衛門の米の逸話における、日にちごとの米の粒の数を計算する関数。
    Parameteres
    -----------
    n_days: int
        米を貰う日数 (default : 100)
    Returns
    -------
    list_day_grains : list
        ある日に貰う米の数のリスト (リストの長さはn_daysに等しい)
    list_total_grains : list
        ある日までに累計で貰う米の数のリスト (リストの長さはn_daysに等しい)
    """
    amount = 1
    day = 1

    list_day_grain = [1]
    list_total_grain = [1]

    for _ in range(n_days-1):
        day *= 2
        list_day_grain.append(day)
        amount += day
        list_total_grain.append(amount)
    # ここにコードを書く。passは何もしないことを意味する命令である。
    
    pass
    return list_day_grain, list_total_grain

target = 10

list_day_grain, list_total_grain = compute_sorori_shinzaemon(n_days=target)

print(list_day_grain)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("amount of rice")
plt.xlabel("day")
plt.ylabel("count")
plt.plot(list_day_grain, label="day_grains")  # 「リスト名」のところにリストの変数名を入れる
plt.plot(list_total_grain, label="total_grains")  # 「リスト名」のところにリストの変数名を入れる
plt.legend()
plt.show()

# %% [markdown]
# 【問題3】貰える米で何人が何日生活できるか

# %%
people = 14
"""
仮定
米1日必要最低限量で計算する
１人1日最低必要量　：　茶碗２杯　× 3,250粒　= 6,500粒
"""

def compute_sorori_2(people=14):
    """この米があれば何人が何日生活できるか計算する関数。
    Parameteres
    -----------
    amount : 
        米粒の数
    people :
        生活できる人数
    
    Returns
    -------
    survive_day : 
        生活できる日数

    """
    survive_day = amount / people / day
    
    pass
    return survive_day

target = 10


compute_sorori_2(people=)
print(list_day_grain)
