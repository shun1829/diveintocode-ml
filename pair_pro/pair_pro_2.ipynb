# %%
import numpy as np

mean_1 = (-3, 0)
cov = [[1.0, 0.8], [0.8, 1.0]]

np.random.seed(0)
np.random.multivariate_normal(mean , cov, 500)
#np.random.seed(0)
# Out:
# array([[-4.80006782e+00, -1.54698618e+00],
#        [-4.63714503e+00, -2.19879728e-01],
#        [-4.46267867e+00, -2.08076347e+00],
#        [-3.85346966e+00, -9.49196365e-01],
#        [-3.03192065e+00,  2.27764648e-01],
#        [-3.59653339e+00,  3.23229932e-01],
#        [-3.76046080e+00, -6.83506760e-01],
#        [-3.52660272e+00, -3.15568548e-01],
#        [-4.35253112e+00, -1.48228460e+00],
#        [-3.02691331e+00, -5.67090887e-01],
#        [-7.84713550e-01,  2.62867115e+00],
#        [-3.58538300e+00, -1.05476937e+00],
#        [-4.69336749e+00, -2.61318911e+00],
#        [-2.98421761e+00, -1.02603072e-01],
#        [-4.91877408e+00, -9.89469999e-01],
#        [-3.26658152e+00, -2.74105461e-02],
#        [-1.53138965e+00,  2.15844669e-01],
#        [-2.71938344e+00,  3.79500330e-01],
#        [-4.54738211e+00, -7.86930327e-01],
#        [-2.53695299e+00,  2.71853959e-01],
#        [-1.55620621e+00,  5.45695585e-01],
#        [-1.99817931e+00,  2.23559938e+00],
# ...

# %%
import matplotlib.pyplot as plt

a = np.random.multivariate_normal(mean , cov, 500)

a_0 = a[:, 0]
a_1 = a[:, 1]

#plt.scatter(a_0,　a_1)
plt.scatter(a_0, a_1)
plt.show()

# %%
plt.hist(a_0)
plt.xlim(-10, 10)
plt.show()

# %%
plt.hist(a_1)
plt.xlim(-10, 10)
plt.show()

# %%
mean_2 = (0, -3)
cov = [[1.0, 0.8], [0.8, 1.0]]

np.random.seed(0)
np.random.multivariate_normal(mean_2 , cov, 500)

b = np.random.multivariate_normal(mean_2 , cov, 500)
a_2 = b[:, 0]
a_3 = b[:, 1]


#np.random.seed(0)
plt.scatter(a_0, a_1, label="0")
plt.scatter(a_2, a_3, label="1")
plt.legend()
plt.show()

# %%
np.concatenate((a, b))
# Out:
# array([[-3.80965753, -0.24520748],
#        [-2.63247046,  0.4337565 ],
#        [-3.28006393, -0.15263683],
#        ...,
#        [-0.2185878 , -3.15676476],
#        [-1.37970304, -4.27950068],
#        [ 1.49786804, -2.33126243]])

# %%
zero_array = np.zeros(500)
one_array = np.ones(500)

c = np.concatenate((zero_array, one_array))

d = np.concatenate((a, b))

np.insert(d, 2 , c, axis=1)
# Out:
# array([[-3.80965753, -0.24520748,  0.        ],
#        [-2.63247046,  0.4337565 ,  0.        ],
#        [-3.28006393, -0.15263683,  0.        ],
#        ...,
#        [-0.2185878 , -3.15676476,  1.        ],
#        [-1.37970304, -4.27950068,  1.        ],
#        [ 1.49786804, -2.33126243,  1.        ]])
